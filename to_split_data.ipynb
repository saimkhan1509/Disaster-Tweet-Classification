# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # To Split the Images into test ,train and validation

# %%
import os
import pandas as pd
#df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CrisisMMD_v2.0/crisismmd_datasplit_all/task_informative_text_img_train.tsv", sep='\t')
#df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CrisisMMD_v2.0/crisismmd_datasplit_all/task_humanitarian_text_img_dev.tsv", sep='\t')
#df3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CrisisMMD_v2.0/crisismmd_datasplit_all/task_informative_text_img_test.tsv", sep='\t')

#df=pd.concat([df2,df3], ignore_index=True)
labels = df.sort_values('label')
class_names = list(labels.label_image.unique())

train_images ='/content/drive/MyDrive/Colab Notebooks/CrisisMMD_v2.0/'
train_cat = '/content/drive/MyDrive/Colab Notebooks/val2'
for i in class_names:
  os.makedirs(os.path.join('/content/drive/MyDrive/Colab Notebooks/val2', i))
import shutil
for c in class_names: # Category Name
  for i in list(labels[labels['label']==c]['image']): # Image Id
    get_image = os.path.join('/content/drive/MyDrive/Colab Notebooks/CrisisMMD_v2.0/', i) # Path to Images
    move_image_to_cat = shutil.copy(get_image, '/content/drive/MyDrive/Colab Notebooks/val2/'+c)

df3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CrisisMMD_v2.0/crisismmd_datasplit_all/task_humanitarian_text_img_test.tsv", sep='\t')

#df=pd.concat([df2,df3], ignore_index=True)
labels = df3.sort_values('label')
class_names = list(labels.label_image.unique())

train_images ='/content/drive/MyDrive/Colab Notebooks/CrisisMMD_v2.0/'
train_cat = '/content/drive/MyDrive/Colab Notebooks/test2'
for i in class_names:
  os.makedirs(os.path.join('/content/drive/MyDrive/Colab Notebooks/test2', i))
import shutil
for c in class_names: # Category Name
  for i in list(labels[labels['label']==c]['image']): # Image Id
    get_image = os.path.join('/content/drive/MyDrive/Colab Notebooks/CrisisMMD_v2.0/', i) # Path to Images
    move_image_to_cat = shutil.copy(get_image, '/content/drive/MyDrive/Colab Notebooks/test2/'+c)

# %% [markdown]
# # New Section
